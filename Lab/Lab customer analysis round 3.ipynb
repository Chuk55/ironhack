# %% [markdown]
# # Lab customer analysis round 3

# %% [markdown]
# ### Read the file into python as dataframes

# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('/Users/Admin/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
### show the DataFrames shape

# %%
file1.shape
# Out:
# (9134, 24)

# %% [markdown]
# ### Standardize header names.

# %%
print(file1.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower().replace(' ', '_'))
file1.columns = cols
print(file1.columns)
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
column_names = file1.columns
column_names

data = pd.DataFrame(columns=column_names)
data
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### Concatenate the three dataframes

# %%
data = pd.concat([data,file1], axis=0)
data.shape
# Out:
# (9134, 24)

# %% [markdown]
# ### Which columns are numerical?

# %%
data.select_dtypes('float')
# Out:
#       customer_lifetime_value  total_claim_amount
# 0                 2763.519279          384.811147
# 1                 6979.535903         1131.464935
# 2                12887.431650          566.472247
# 3                 7645.861827          529.881344
# 4                 2813.692575          138.130879
# ...                       ...                 ...
# 9129             23405.987980          198.234764
# 9130              3096.511217          379.200000
# 9131              8163.890428          790.784983
# 9132              7524.442436          691.200000
# 9133              2611.836866          369.600000
#
# [9134 rows x 2 columns]

# %% [markdown]
# ### Which columns are categorical?

# %%
data.select_dtypes('object')
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      employmentstatus gender income location_code  ...  \
# ...

# %% [markdown]
# ### Check and deal with NaN values

# %%
file1['effective_to_date'].unique()
# Out:
# array(['2/24/11', '1/31/11', '2/19/11', '1/20/11', '2/3/11', '1/25/11',
#        '1/18/11', '1/26/11', '2/17/11', '2/21/11', '1/6/11', '2/6/11',
#        '1/10/11', '1/17/11', '1/5/11', '2/27/11', '1/14/11', '1/21/11',
#        '2/5/11', '1/29/11', '2/28/11', '2/12/11', '2/2/11', '2/7/11',
#        '1/22/11', '2/13/11', '1/15/11', '1/8/11', '1/11/11', '1/28/11',
#        '2/8/11', '2/23/11', '1/2/11', '2/16/11', '1/27/11', '1/23/11',
#        '1/9/11', '2/11/11', '2/4/11', '2/1/11', '2/15/11', '2/26/11',
#        '1/16/11', '1/1/11', '2/10/11', '1/24/11', '2/25/11', '1/12/11',
#        '2/9/11', '1/19/11', '1/4/11', '2/14/11', '2/20/11', '2/18/11',
#        '1/3/11', '1/13/11', '1/30/11', '2/22/11', '1/7/11'], dtype=object)

# %%
data[data['effective_to_date'].isna()==True]
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ### Datetime format.

# %%
file1['effective_to_date'] = pd.to_datetime(file1['effective_to_date'], errors='coerce')

# %%
file1['effective_to_date']
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %% [markdown]
# ### BONUS: Put all the previously mentioned data transformations into a function.

# %%
file1.shape
# Out:
# (9134, 24)

# %%
file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
file1.describe(include='all')
# Out:
#        customer       state  customer_lifetime_value response coverage  \
# count      9134        9134              9134.000000     9134     9134
# unique     9134           5                      NaN        2        3
# top     SA77508  California                      NaN       No    Basic
# freq          1        3150                      NaN     7826     5568
# first       NaN         NaN                      NaN      NaN      NaN
# last        NaN         NaN                      NaN      NaN      NaN
# mean        NaN         NaN              8004.940475      NaN      NaN
# std         NaN         NaN              6870.967608      NaN      NaN
# min         NaN         NaN              1898.007675      NaN      NaN
# 25%         NaN         NaN              3994.251794      NaN      NaN
# 50%         NaN         NaN              5780.182197      NaN      NaN
# 75%         NaN         NaN              8962.167041      NaN      NaN
# ...

# %%
file1.describe(include=[np.object])
# Out:
#        customer       state response coverage education employmentstatus  \
# count      9134        9134     9134     9134      9134             9134
# unique     9134           5        2        3         5                5
# top     SA77508  California       No    Basic  Bachelor         Employed
# freq          1        3150     7826     5568      2748             5698
#
#        gender location_code marital_status    policy_type       policy  \
# count    9134          9134           9134           9134         9134
# unique      2             3              3              3            9
# top         F      Suburban        Married  Personal Auto  Personal L3
# freq     4658          5779           5298           6788         3426
#
#        renew_offer_type sales_channel  vehicle_class vehicle_size
# count              9134          9134           9134         9134
# unique                4             4              6            3
# ...

# %%
file1.describe(include=[np.number])
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns #newer library
# %matplotlib inline

# %%
file1['response'].hist()
plt.show()

# %%
sns.barplot(x="response", y="sales_channel", data=file1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-8dbc254e92e4> in <module>
# ----> 1 sns.barplot(x="response", y="sales_channel", data=file1)
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
file1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %%
categoricals = file1.describe(include=[np.object])

# %%
categoricals.head()
# Out:
#        customer       state response coverage education employmentstatus  \
# count      9134        9134     9134     9134      9134             9134
# unique     9134           5        2        3         5                5
# top     SA77508  California       No    Basic  Bachelor         Employed
# freq          1        3150     7826     5568      2748             5698
#
#        gender location_code marital_status    policy_type       policy  \
# count    9134          9134           9134           9134         9134
# unique      2             3              3              3            9
# top         F      Suburban        Married  Personal Auto  Personal L3
# freq     4658          5779           5298           6788         3426
#
#        renew_offer_type sales_channel  vehicle_class vehicle_size
# count              9134          9134           9134         9134
# unique                4             4              6            3
# ...

# %%
numerical = file1.describe(include=[np.number])

# %%
numerical.head()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# count                9134.000000         9134.000000         9134.000000
# ...

# %%
file1['customer_lifetime_value'].hist()
plt.show()

# %%
file1['income'].hist()
plt.show()

# %%
file1['monthly_premium_auto'].hist()
plt.show()

# %%
df1 = pd.DataFrame(numerical)

# %%
# Out:
#                   variable        value
# 0  customer_lifetime_value  9134.000000
# 1  customer_lifetime_value  8004.940475
# 2  customer_lifetime_value  6870.967608
# 3  customer_lifetime_value  1898.007675
# 4  customer_lifetime_value  3994.251794

# %%
## use seaborn library to construct distribution example
for i, col in enumerate(numerical.columns):
    plt.figure(i)
    sns.displot(x=col, data=numerical)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-a26443795634> in <module>
#       2 for i, col in enumerate(numerical.columns):
#       3     plt.figure(i)
# ----> 4     sns.displot(x=col, data=numerical)
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
numerical.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies',
#        'total_claim_amount'],
#       dtype='object')

# %%
for i, col in enumerate(numerical.columns):
    plt.figure(i)
    sns.displot(x=col, data=numerical)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-e50c1b99288d> in <module>
#       1 for i, col in enumerate(numerical.columns):
#       2     plt.figure(i)
# ----> 3     sns.displot(x=col, data=numerical)
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
sns.displot('customer_lifetime_value',)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-6427df3d9a80> in <module>
# ----> 1 sns.displot('customer_lifetime_value',)
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
sns.distplot(file1['customer_lifetime_value'])
